# %%
import torch
torch.cuda.empty_cache()

# %%
# !yolo train data=/home/wahrwelt/Downloads/Dataset/Lacuna_Malaria_Dataset/Thick_Ghana/data/data.yaml model=yolo11n.pt epochs=60
# Out:
# Ultralytics 8.3.96 🚀 Python-3.12.3 torch-2.3.1+cu121 CPU (12th Gen Intel Core(TM) i7-12800H)
# ...
